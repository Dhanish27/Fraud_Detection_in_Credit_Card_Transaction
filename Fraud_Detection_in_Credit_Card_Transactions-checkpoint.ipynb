# %% [markdown]
# ### Import the libraries necessary for our project.

# %%
import pandas as pd
from pandas.plotting import scatter_matrix
import numpy as np
import matplotlib.pyplot as plt
import os
from imblearn.over_sampling import ADASYN 
from collections import Counter
import seaborn as sn
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.naive_bayes import BernoulliNB 
from sklearn import metrics

# %% [markdown]
# ### To get the full view of the output

# %%
pd.set_option('display.max_row',None)
pd.set_option('display.max_column',None)

# %% [markdown]
# ### Create plot functions.

# %%
def plot_confusion_matrix(cm, classes, title, cmap):
    "function for plotting confusion matrix"
    plt.clf()
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    classnames = classes
    plt.title(title)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    tick_marks = np.arange(len(classnames))
    plt.xticks(tick_marks, classnames, rotation=45)
    plt.yticks(tick_marks, classnames)
    s = [['TN','FP'], ['FN', 'TP']]
    for i in range(2):
        for j in range(2):
            plt.text(j,i, str(s[i][j])+" = "+str(cm[i][j]))
    plt.show()

def plot_roc_auc(arg1, arg2, arg3):
    "a function to plot roc_auc"
    fig, ax = plt.subplots(figsize=(8, 6))
    for i, v in arg1: 
        y_score = v.predict_proba(arg2)[:, 1]
        fpr, tpr, _ = metrics.roc_curve(arg3, y_score) 
        roc_auc = metrics.auc(fpr, tpr)
        plt.plot(fpr, tpr,lw=2, label= i + ' (area = %0.2f)' % roc_auc) 
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve')
    plt.legend(loc="lower right")
    plt.show()

# %% [markdown]
# ### Set the graph setting

# %%
# %matplotlib inline
sn.set_style("dark")
sn.set_palette("colorblind")

# %% [markdown]
# ### Load Data:
# The data is found in the kaggle and use the link to access it :
# https://www.kaggle.com/mlg-ulb/creditcardfraud/data

# %%
df = pd.read_csv("D:/datasets/creditcard.csv")

# %%
df.head(5)      #for viewing first 5 rows of data
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %%
df.describe()        # for general description of data
# Out:
#                 Time           V1           V2           V3           V4  \
# count    4007.000000  4007.000000  4007.000000  4007.000000  4007.000000
# mean    15137.552783    -0.826774     0.685033     0.002531     0.916752
# std     29991.507165     3.171640     2.241418     3.775019     2.096450
# min         0.000000   -30.552380   -25.640527   -31.103685    -4.657545
# 25%       755.500000    -1.275585    -0.132772     0.180638    -0.224525
# 50%      8170.000000    -0.430900     0.363232     0.846517     0.501414
# 75%     10563.500000     1.131473     1.098875     1.609651     1.451907
# max    170348.000000     2.132386    22.057729     4.017561    12.114672
#
#                 V5           V6           V7           V8           V9  \
# count  4007.000000  4007.000000  4007.000000  4007.000000  4007.000000
# mean     -0.463857    -0.122620    -0.746003    -0.033757     0.473122
# std       2.360113     1.364435     3.232894     2.643567     1.843811
# ...

# %%
# for determining the number of records in the dataset
print('The dataset contains {0} rows and {1} columns.'.format(df.shape[0], df.shape[1]))
# Out:
# The dataset contains 4007 rows and 31 columns.

# %%
# check for missing values and data types of the columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4007 entries, 0 to 4006
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    4007 non-null   int64
#  1   V1      4007 non-null   float64
#  2   V2      4007 non-null   float64
#  3   V3      4007 non-null   float64
#  4   V4      4007 non-null   float64
#  5   V5      4007 non-null   float64
#  6   V6      4007 non-null   float64
#  7   V7      4007 non-null   float64
#  8   V8      4007 non-null   float64
#  9   V9      4007 non-null   float64
#  10  V10     4007 non-null   float64
#  11  V11     4007 non-null   float64
#  12  V12     4007 non-null   float64
#  13  V13     4007 non-null   float64
#  14  V14     4007 non-null   float64
#  15  V15     4007 non-null   float64
#  16  V16     4007 non-null   float64
#  17  V17     4007 non-null   float64
#  18  V18     4007 non-null   float64
#  19  V19     4007 non-null   float64
# ...

# %% [markdown]
# ### Determine the distribution of the label class

# %%
print('Normal transactions count: ', df['Class'].value_counts().values[0])
print('Fraudulent transactions count: ', df['Class'].value_counts().values[1])
# Out:
# Normal transactions count:  3491
# Fraudulent transactions count:  516

# %% [markdown]
# ### Seperate the predictor from the labels

# %%
# feature data (predictors)
X = df.iloc[:, :-1]
# label class
y = df['Class']

# %% [markdown]
# ### Standardize Data

# %%
scaler = StandardScaler()
scaled_X = scaler.fit_transform(X)

# %% [markdown]
# ### Partition dataset into train and test set

# %%
X_train, X_test, y_train, y_test = train_test_split(scaled_X, y, test_size=0.30, random_state=42)

# %% [markdown]
# ### Data Sampling :
# The dataset is imbalance, that is one class is dominant and the other class is minor.This may lead to misclassification of minority class. Therefore, to compensate for the unbalancedness, we will use ADASYN oversampling method as implemented in imbalanced-learn package to resample the dataset.ADASYN (ADAptive SYNthetic) is an oversampling technique that adaptively generates minority data samples according to their distributions using K nearest neighbor.

# %%
ada = ADASYN(random_state=42)
print('Original dataset shape {}'.format(Counter(y_train)))
X_res, y_res = ada.fit_resample(X_train, y_train)
print('Resampled dataset shape {}'.format(Counter(y_res)))
# Out:
# Original dataset shape Counter({0: 2449, 1: 355})
# Resampled dataset shape Counter({0: 2449, 1: 2446})

# %% [markdown]
# ### Train models
# Two machine learing models are used : Logistic Regression and RandomForest classifiers were used to the process feature data.

# %%
X_train, y_train = X_res, y_res 

# Train LogisticRegression Model
LGR_Classifier = LogisticRegression()
LGR_Classifier.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
# Train Decision Tree Model
RDF_Classifier = RandomForestClassifier(random_state=0)
RDF_Classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
# Train Bernoulli Naive Baye Model
BNB_Classifier = BernoulliNB()
BNB_Classifier.fit(X_train, y_train)
# Out:
# BernoulliNB()

# %% [markdown]
# ### Evaluate Models

# %%
modlist = [('RandomForest Classifier', RDF_Classifier),('LogisticRegression', LGR_Classifier),
('Naive Baiye Classifier', BNB_Classifier)] 

models = [j for j in modlist]

print()
print('========================== Model Evaluation Results ========================' "\n")  

for i, v in models:
    scores = cross_val_score(v, X_train, y_train, cv=10)
    accuracy = metrics.accuracy_score(y_train, v.predict(X_train))
    confusion_matrix = metrics.confusion_matrix(y_train, v.predict(X_train))
    classification = metrics.classification_report(y_train, v.predict(X_train))
    print('===== {} ====='.format(i))
    print()
    print ("Cross Validation Mean Score: ", '{}%'.format(np.round(scores.mean(), 3) * 100))  
    print() 
    print ("Model Accuracy: ", '{}%'.format(np.round(accuracy, 3) * 100)) 
    print()
    print("Confusion Matrix:" "\n", confusion_matrix)
    print()
    print("Classification Report:" "\n", classification) 
    print()
# Out:
# ========================== Model Evaluation Results ========================
#
# ===== RandomForest Classifier =====
#
# Cross Validation Mean Score:  100.0%
#
# Model Accuracy:  100.0%
#
# Confusion Matrix:
#  [[2449    0]
#  [   0 2446]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2449
#            1       1.00      1.00      1.00      2446
#
#     accuracy                           1.00      4895
#    macro avg       1.00      1.00      1.00      4895
# weighted avg       1.00      1.00      1.00      4895
#
#
# ===== LogisticRegression =====
#
# Cross Validation Mean Score:  99.8%
#
# Model Accuracy:  100.0%
#
# Confusion Matrix:
#  [[2447    2]
#  [   0 2446]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2449
#            1       1.00      1.00      1.00      2446
#
# ...

# %% [markdown]
# ### Test Model

# %%
classdict = {'normal':0, 'fraudulent':1}
print()
print('========================== Model Test Results ========================' "\n")   

for i, v in models:
    accuracy = metrics.accuracy_score(y_test, v.predict(X_test))
    confusion_matrix = metrics.confusion_matrix(y_test, v.predict(X_test))
    classification = metrics.classification_report(y_test, v.predict(X_test))   
    print('=== {} ==='.format(i))
    print ("Model Accuracy: ",  '{}%'.format(np.round(accuracy, 3) * 100))
    print()
    print("Confusion Matrix:" "\n", confusion_matrix)
    print()
    plot_confusion_matrix(confusion_matrix, classes = list(classdict.keys()), title='Confusion Matrix Plot', cmap=plt.cm.summer)
    print() 
    print("Classification Report:" "\n", classification) 
    print() 

print('============================= ROC Curve ===============================' "\n")      
plot_roc_auc(arg1=models, arg2=X_test, arg3=y_test)
# Out:
# ========================== Model Test Results ========================
#
# === RandomForest Classifier ===
# Model Accuracy:  100.0%
#
# Confusion Matrix:
#  [[1042    0]
#  [   0  161]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1042
#            1       1.00      1.00      1.00       161
#
#     accuracy                           1.00      1203
#    macro avg       1.00      1.00      1.00      1203
# weighted avg       1.00      1.00      1.00      1203
#
#
# === LogisticRegression ===
# Model Accuracy:  99.7%
#
# Confusion Matrix:
#  [[1038    4]
#  [   0  161]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1042
#            1       0.98      1.00      0.99       161
#
#     accuracy                           1.00      1203
#    macro avg       0.99      1.00      0.99      1203
# ...
